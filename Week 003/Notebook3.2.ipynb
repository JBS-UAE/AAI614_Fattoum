# %% [markdown]
# # AAI614: Data Science & its Applications
#
# *Notebook 3.2: Practice with Data Cleaning*
#
# <a href="https://colab.research.google.com/github/JBS-UAE/AAI614_Fattoum/blob/main/Week%20003/Notebook3.2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import ssl

ssl._create_default_https_context = ssl._create_unverified_context

# %% [markdown]
# Exercise I. Load the following datafile from GitHub

# %%
grads = pd.read_csv("https://raw.githubusercontent.com/harmanani/AAI614/main/Week%203/grads.csv")

# %%
grads
# Out:
#   Student Name  Avg Hours Studies per Week  GPA     University  \
# 0       George                          20  NaN            NYU
# 1        Jerry                          35  3.5       Columbia
# 2       Elaine                          55  4.0       Columbia
# 3        Cosmo                           5  2.0   City College
# 4       Newman                          25  2.8   City College
# 5        Frank                          35  3.0   Festivus Uni
# 6      Estelle                         100  3.2  Festivus Uni
# 7          Leo                          15  2.4   Festivus Uni
# 8       Rachel                          50  4.0       Columbia
#
#    Sense of Humour (0-5) Salary
# 0                    3.0   $40k
# 1                    5.0   $80k
# 2                    4.2   $60k
# 3                    2.0   $25k
# 4                    0.0   $50k
# 5                    NaN   $40k
# 6                    1.7    $0k
# 7                    0.0   $35k
# 8                    NaN   $75k

# %% [markdown]
# Question 1: Identify all the outliers in the above data.  Justify your answers using objective measures.

# %%
#define numerical columns to skip student name and university name
numerical_columns = ["Avg Hours Studies per Week", "GPA", "Sense of Humour (0-5)"]

#create results dataframe to store q1, q3, iqr, lower bound and upper bound
results = {}

#calculate q1, q3, iqr, lower bound and upper bound
for col in numerical_columns:
    q1 = grads[col].quantile(0.25)
    q3 = grads[col].quantile(0.75)
    iqr = q3 - q1
    lower_bound = q1 - 1.5 * iqr
    upper_bound = q3 + 1.5 * iqr
    
    #outliers
    outliers = grads[col][(grads[col] < lower_bound) | (grads[col] > upper_bound)].values
    
    #results storing
    results[col] = {
        "Q1": q1,
        "Q3": q3,
        "IQR": iqr,
        "Lower Bound": lower_bound,
        "Upper Bound": upper_bound,
        "Outliers": list(outliers)
    }

#IQR  & outliers
iqr_results_df = pd.DataFrame(results).T
print(iqr_results_df)
# Out:
#                               Q1     Q3    IQR Lower Bound Upper Bound  \
# Avg Hours Studies per Week  20.0   50.0   30.0       -25.0        95.0
# GPA                          2.7  3.625  0.925      1.3125      5.0125
# Sense of Humour (0-5)       0.85    3.6   2.75      -3.275       7.725
#
#                            Outliers
# Avg Hours Studies per Week    [100]
# GPA                              []
# Sense of Humour (0-5)            []

# %% [markdown]
# Question 2: There are various data that are missing.  Fill-in the missing data or delete the rows/columns that you think you should delete.  Justify your answer

# %% [markdown]
# # Answer
# 1. After careful analysis of the dataset i found that GPA missing data i calcultaed the missing persentage = ((1/9)*100)=11% which is a smale percentage but because GPA is important factor to our analysis we can fill the missing value by inserting the mean = ((3.5+4.0+2.0+2.8+3.0+3.2+2.4+4.0)/8)=3.1
# 2. Sense of Humor missing data percentage = ((2/9)*100) = 22%, its a big percentage but sense of humor is not a factor that affect our analysis so we can delete the missing data

# %%
#insert mean of GPA in the missing value
grads["GPA"].fillna(grads["GPA"].median(), inplace=True)

#drop missing values of sense of humor
grads.dropna(subset=["Sense of Humour (0-5)"], inplace=True)

#print modified dataset
grads
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_16656\3019328663.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   grads["GPA"].fillna(grads["GPA"].median(), inplace=True)
#   Student Name  Avg Hours Studies per Week  GPA     University  \
# 0       George                          20  3.1            NYU
# 1        Jerry                          35  3.5       Columbia
# 2       Elaine                          55  4.0       Columbia
# 3        Cosmo                           5  2.0   City College
# ...

# %% [markdown]
# Question 3: Reload the data and fill-in the data using mean method as well as the frequent method.

# %%
#reload the grads dataset
grads = pd.read_csv("https://raw.githubusercontent.com/harmanani/AAI614/main/Week%203/grads.csv")

#insert mean of GPA in the missing value
grads["GPA"].fillna(grads["GPA"].mean(), inplace=True)

#insert missing data in sense of humor using mode
grads["Sense of Humour (0-5)"].fillna(grads["Sense of Humour (0-5)"].mode()[0], inplace=True)

#print modified dataset
grads
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_16656\3251510625.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   grads["GPA"].fillna(grads["GPA"].mean(), inplace=True)
# C:\Users\User\AppData\Local\Temp\ipykernel_16656\3251510625.py:8: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %% [markdown]
# Exercise II. Run the cell below to create a new dataframe called `df_miss`.  Its first column will contain some missing values.

# %%
import pandas as pd
import numpy as np
import random

nrows = 10
ncols = 5

# set a seed for random number generation
np.random.seed(314)
# create an array filled with random data
data = np.array(np.random.rand(nrows, ncols))
# put the data to a pandas dataframe
df_miss = pd.DataFrame(data)
# rename the columns
df_miss.columns = ['col_'+str(ii) for ii in range(ncols)]

# randomly set some values to missing
ix0 = np.random.randint(nrows, size=3)
ix1 = np.random.randint(nrows, size=3)

df_miss['col_0'][ix0] = np.nan
df_miss['col_1'][ix1] = np.nan

print(df_miss)
# Out:
#       col_0     col_1     col_2     col_3     col_4
# 0       NaN       NaN  0.265048  0.783205  0.918001
# 1  0.827355       NaN  0.260480  0.911763  0.260757
# 2  0.766376  0.261531  0.122291  0.386006  0.840081
# 3       NaN       NaN  0.633110  0.584766  0.581232
# 4  0.677205  0.687155  0.438927  0.320927  0.570552
# 5       NaN  0.861074  0.834805  0.105766  0.060408
# 6  0.596882  0.792395  0.226356  0.535201  0.136066
# 7  0.372244  0.151977  0.429822  0.792706  0.406957
# 8  0.177850  0.909252  0.545331  0.100497  0.718721
# 9  0.978429  0.309776  0.260126  0.662900  0.139720
# C:\Users\User\AppData\Local\Temp\ipykernel_16656\310065607.py:21: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# ...

# %% [markdown]
# Impute the missing values (NaN) in `col_0` (but not `col_1`) with the median.  Store the values in the dataframe by using the parameter `inplace`.  Print the dataframe.

# %%
#impute the missing values (NAN) in 'col_0' with its median
df_miss['col_0'].fillna(df_miss['col_0'].median(), inplace=True)

#print modified DataFrame
print(df_miss)
# Out:
#       col_0     col_1     col_2     col_3     col_4
# 0  0.677205       NaN  0.265048  0.783205  0.918001
# 1  0.827355       NaN  0.260480  0.911763  0.260757
# 2  0.766376  0.261531  0.122291  0.386006  0.840081
# 3  0.677205       NaN  0.633110  0.584766  0.581232
# 4  0.677205  0.687155  0.438927  0.320927  0.570552
# 5  0.677205  0.861074  0.834805  0.105766  0.060408
# 6  0.596882  0.792395  0.226356  0.535201  0.136066
# 7  0.372244  0.151977  0.429822  0.792706  0.406957
# 8  0.177850  0.909252  0.545331  0.100497  0.718721
# 9  0.978429  0.309776  0.260126  0.662900  0.139720
# C:\Users\User\AppData\Local\Temp\ipykernel_16656\7835278.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %% [markdown]
# Impute the missing values in `col_1` with value 0.  Store the values in the dataframe by using the parameter `inplace`.  Print the dataframe.

# %%
#impute the missing values (NAN) in 'col_0' with value 0
df_miss['col_1'].fillna(0, inplace=True)

#print modified DataFrame
print(df_miss)
# Out:
#       col_0     col_1     col_2     col_3     col_4
# 0  0.677205  0.000000  0.265048  0.783205  0.918001
# 1  0.827355  0.000000  0.260480  0.911763  0.260757
# 2  0.766376  0.261531  0.122291  0.386006  0.840081
# 3  0.677205  0.000000  0.633110  0.584766  0.581232
# 4  0.677205  0.687155  0.438927  0.320927  0.570552
# 5  0.677205  0.861074  0.834805  0.105766  0.060408
# 6  0.596882  0.792395  0.226356  0.535201  0.136066
# 7  0.372244  0.151977  0.429822  0.792706  0.406957
# 8  0.177850  0.909252  0.545331  0.100497  0.718721
# 9  0.978429  0.309776  0.260126  0.662900  0.139720
# C:\Users\User\AppData\Local\Temp\ipykernel_16656\3333844149.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...
